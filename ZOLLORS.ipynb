# %%
from DSA_PROJECT import *
# Out:
# ***WELCOME TO ZOLLORS***
# ------------------------------------
# SIGN-UP/LOGIN
# 1👉Sign-up for new account
# 2👉Login to your existing account
# ------------------------------------
# Enter your choice...2
# USERNAME: akshaya
# PASSWORD: akshaya123
#
# hi  akshaya
# U HAVE SUCCESSFULLY SIGNED IN👍
#
#
# ***WHAT WOULD YOU WISH TO DO🤔***
# 1👉Mine a new block
# 2👉View my transactions list
# 3👉View entire blockchain
# 4👉Exit Application
# Enter your choice...2
# +------------+-------------------------------------------+
# |   block no | transactions                              |
# +============+===========================================+
# |          1 | null                                      |
# +------------+-------------------------------------------+
# |          2 | [a sent Rs.15000 to b]                    |
# |            | [c sent Rs.5000 to d]                     |
# +------------+-------------------------------------------+
# ...
